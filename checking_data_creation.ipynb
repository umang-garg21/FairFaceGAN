# %%
from datasets import load_from_disk

# %%
dataset = load_from_disk('./ff_prompts_only')

# %%
dataset["train"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 dataset["train"]
#
# File ~/fairface/lib/python3.9/site-packages/datasets/arrow_dataset.py:2658, in Dataset.__getitem__(self, key)
#    2656 def __getitem__(self, key):  # noqa: F811
#    2657     """Can be used to index columns (by string names) or rows (by integer index or iterable of indices or bools)."""
# -> 2658     return self._getitem(key)
#
# File ~/fairface/lib/python3.9/site-packages/datasets/arrow_dataset.py:2642, in Dataset._getitem(self, key, **kwargs)
#    2640 format_kwargs = format_kwargs if format_kwargs is not None else {}
#    2641 formatter = get_formatter(format_type, features=self.features, **format_kwargs)
# -> 2642 pa_subtable = query_table(self._data, key, indices=self._indices if self._indices is not None else None)
#    2643 formatted_output = format_table(
# ...

# %%
dataset['text']
# Out:
# ['face of East Asian person',
#  'face of Indian person',
#  'face of Black person',
#  'face of Indian person',
#  'face of Indian person',
#  'face of White person',
#  'face of Middle Eastern person',
#  'face of Indian person',
#  'face of White person',
#  'face of Middle Eastern person',
#  'face of East Asian person',
#  'face of East Asian person',
#  'face of Latino Hispanic  person',
#  'face of Indian person',
#  'face of Indian person',
#  'face of White person',
#  'face of Southeast Asian person',
#  'face of Southeast Asian person',
#  'face of Black person',
#  'face of Southeast Asian person',
#  'face of Indian person',
#  'face of Middle Eastern person',
#  'face of Black person',
#  'face of White person',
#  'face of White person',
#  'face of Black person',
#  'face of White person',
#  'face of White person',
#  'face of Indian person',
#  'face of Black person',
#  'face of Black person',
#  'face of East Asian person',
#  'face of White person',
# ...
